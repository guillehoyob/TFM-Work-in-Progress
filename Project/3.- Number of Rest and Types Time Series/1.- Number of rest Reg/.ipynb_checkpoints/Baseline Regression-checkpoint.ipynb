# %% [markdown]
# # Baseline Prediction

# %% [markdown]
# https://towardsdatascience.com/multivariate-time-series-forecasting-using-random-forest-2372f3ecbad1

# %% [markdown]
# # <span style='background :khaki' > Install & Importa Libraries </span>

# %%
### ***Enviroment Preparation***
# Install Pandas
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# !pip install lightgbm

# !pip install dtale

# !pip install sktime
# !pip install sklego

#!pip install skforecast

# Update pip -- WARNING Resolution
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pandas in c:\users\ghoyo\miniconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\ghoyo\miniconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\ghoyo\miniconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from seaborn) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\ghoyo\miniconda3\lib\site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\ghoyo\miniconda3\lib\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\ghoyo\miniconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: lightgbm in c:\users\ghoyo\miniconda3\lib\site-packages (3.3.5)
# Requirement already satisfied: scipy in c:\users\ghoyo\miniconda3\lib\site-packages (from lightgbm) (1.9.3)
# Requirement already satisfied: numpy in c:\users\ghoyo\miniconda3\lib\site-packages (from lightgbm) (1.23.4)
# Requirement already satisfied: wheel in c:\users\ghoyo\miniconda3\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from lightgbm) (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: dtale in c:\users\ghoyo\miniconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: dash-daq in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: Flask in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (2.2.3)
# Requirement already satisfied: squarify in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: pandas in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.5.1)
# Requirement already satisfied: strsimpy in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: xlrd in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: lz4 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (4.3.2)
# Requirement already satisfied: matplotlib==3.6.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (3.6.0)
# Requirement already satisfied: dash-bootstrap-components<=1.3.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.3.1)
# Requirement already satisfied: future>=0.14.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.18.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (4.11.2)
# Requirement already satisfied: kaleido in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (3.1.2)
# Requirement already satisfied: scikit-learn in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.1.3)
# Requirement already satisfied: Flask-Compress in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.13)
# Requirement already satisfied: itsdangerous in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (2.1.2)
# Requirement already satisfied: six in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: numpy in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.23.4)
# Requirement already satisfied: scipy==1.9.3 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.9.3)
# Requirement already satisfied: seaborn in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.12.1)
# Requirement already satisfied: dash>=2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (2.8.1)
# Requirement already satisfied: dash-colorscales in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: networkx in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (3.0)
# Requirement already satisfied: statsmodels in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.13.5)
# Requirement already satisfied: xarray in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (2023.2.0)
# Requirement already satisfied: et-xmlfile in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (5.13.1)
# Requirement already satisfied: cycler in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.11.0)
# Requirement already satisfied: requests in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (2.27.1)
# Requirement already satisfied: certifi in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (2021.10.8)
# Requirement already satisfied: missingno<=0.4.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: flask-ngrok in c:\users\ghoyo\miniconda3\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (4.38.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from dash>=2.0.0->dtale) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: click>=8.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from Flask->dtale) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from Flask->dtale) (3.0.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from Flask->dtale) (4.8.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from Flask->dtale) (2.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from plotly>=5.0.0->dtale) (8.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from beautifulsoup4->dtale) (2.4)
# Requirement already satisfied: brotli in c:\users\ghoyo\miniconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas->dtale) (2022.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from requests->dtale) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from requests->dtale) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn->dtale) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn->dtale) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from statsmodels->dtale) (0.5.3)
# Requirement already satisfied: colorama in c:\users\ghoyo\miniconda3\lib\site-packages (from click>=8.0->Flask->dtale) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from importlib-metadata>=3.6.0->Flask->dtale) (3.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from Jinja2>=3.0->Flask->dtale) (2.1.2)
# Requirement already satisfied: sktime in c:\users\ghoyo\miniconda3\lib\site-packages (0.16.1)
# Requirement already satisfied: numba>=0.53 in c:\users\ghoyo\miniconda3\lib\site-packages (from sktime) (0.56.4)
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from sktime) (1.1.3)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from sktime) (1.9.3)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from sktime) (1.23.4)
# Requirement already satisfied: pandas<1.6.0,>=1.1.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from sktime) (1.5.1)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\ghoyo\miniconda3\lib\site-packages (from sktime) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\ghoyo\miniconda3\lib\site-packages (from deprecated>=1.2.13->sktime) (1.15.0)
# Requirement already satisfied: setuptools in c:\users\ghoyo\miniconda3\lib\site-packages (from numba>=0.53->sktime) (58.0.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\ghoyo\miniconda3\lib\site-packages (from numba>=0.53->sktime) (0.39.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas<1.6.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas<1.6.0,>=1.1.0->sktime) (2022.6)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<1.6.0,>=1.1.0->sktime) (1.16.0)
# Requirement already satisfied: sklego in c:\users\ghoyo\miniconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-lego in c:\users\ghoyo\miniconda3\lib\site-packages (from sklego) (0.6.14)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-lego->sklego) (1.5.1)
# Requirement already satisfied: scikit-learn>=0.24.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-lego->sklego) (1.1.3)
# Requirement already satisfied: umap-learn>=0.4.6 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-lego->sklego) (0.5.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-lego->sklego) (0.5.3)
# Requirement already satisfied: autograd>=1.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-lego->sklego) (1.5)
# Requirement already satisfied: Deprecated>=1.2.6 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-lego->sklego) (1.2.13)
# Requirement already satisfied: numpy>=1.12 in c:\users\ghoyo\miniconda3\lib\site-packages (from autograd>=1.2->scikit-lego->sklego) (1.23.4)
# Requirement already satisfied: future>=0.15.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from autograd>=1.2->scikit-lego->sklego) (0.18.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\ghoyo\miniconda3\lib\site-packages (from Deprecated>=1.2.6->scikit-lego->sklego) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas>=1.1.5->scikit-lego->sklego) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghoyo\miniconda3\lib\site-packages (from pandas>=1.1.5->scikit-lego->sklego) (2022.6)
# Requirement already satisfied: six in c:\users\ghoyo\miniconda3\lib\site-packages (from patsy>=0.5.1->scikit-lego->sklego) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ghoyo\miniconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (1.9.3)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\ghoyo\miniconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (0.5.8)
# Requirement already satisfied: numba>=0.49 in c:\users\ghoyo\miniconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (0.56.4)
# Requirement already satisfied: tqdm in c:\users\ghoyo\miniconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (4.63.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\ghoyo\miniconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\ghoyo\miniconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (58.0.4)
# Requirement already satisfied: colorama in c:\users\ghoyo\miniconda3\lib\site-packages (from tqdm->umap-learn>=0.4.6->scikit-lego->sklego) (0.4.4)
# Requirement already satisfied: pip in c:\users\ghoyo\miniconda3\lib\site-packages (23.0.1)

# %%
### ***Imports***
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import dtale

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from datetime import datetime
from datetime import timedelta

from statsmodels.tsa.stattools import adfuller, kpss

from sklego.preprocessing import RepeatingBasisFunction

from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

import time
# Current Location.. !cd
#C:\Users\ghoyo\Desktop\TFM\Nuevo\Proyect

# Paths
data = r"C:\Users\ghoyo\Desktop\TFM4\Project\GeneratedDfs\dayly_rests.json"

# %% [markdown]
# #### <span style="background:skyblue"> Load Data <span>

# %%
df = pd.read_json(data)
df.shape
# Out:
# (2061, 1)

# %% [markdown]
# #### <span style="background:skyblue"> Little Analysis <span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2061 entries, 2017-04-04 to 2022-11-24
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   n_rests  2061 non-null   int64
# dtypes: int64(1)
# memory usage: 32.2 KB

# %%
df.describe().T
# Out:
#           count      mean       std  min  25%  50%  75%   max
# n_rests  2061.0  5.581756  2.828039  0.0  4.0  5.0  7.0  18.0

# %%
df.head(4)
# Out:
#             n_rests
# 2017-04-04        5
# 2017-04-05        7
# 2017-04-06        7
# 2017-04-07        7

# %% [markdown]
# # <span style='background :khaki' > Baseline Method </span>

# %% [markdown]
# #### <span style="background:violet"> Functions <span>

# %% [markdown]
# #### Baseline 1 = Predict Past Value

# %%
# persistence model
def model_persistence(x):
    return x

# %%
class BlockingTimeSeriesSplit():
    def __init__(self, n_splits):
        self.n_splits = n_splits
    
    def get_n_splits(self, X, y, groups):
        return self.n_splits
    
    def split(self, X, y=None, groups=None):
        n_samples = len(X)
        k_fold_size = n_samples // self.n_splits
        indices = np.arange(n_samples)

        margin = 0
        for i in range(self.n_splits):
            start = i * k_fold_size
            stop = start + k_fold_size
            mid = int(0.999999 * (stop - start)) + start
            yield indices[start: mid], indices[mid + margin: stop]

# %%
class BlockingTimeSeriesSplit():
    def __init__(self, n_splits):
        self.n_splits = n_splits
    
    def get_n_splits(self, X, y, groups):
        return self.n_splits
    
    def split(self, X, y=None, groups=None, num_splits=None):
        n_samples = len(X)
        k_fold_size = n_samples // num_splits
        indices = np.arange(n_samples)

        margin = 0
        for i in range(num_splits):
            start = i * k_fold_size
            stop = start + k_fold_size
            mid = int((i + 1) * n_samples / num_splits)
            yield indices[start: mid], indices[mid + margin: stop]

# %% [markdown]
# ### <span style="background:lightgreen"> Dummy Regresors - lag_1 <span>

# %%
# Create Base Lags
base_df = df.copy()
base_df['n-1'] = base_df['n_rests'].shift(1)
base_df.dropna(inplace = True)
base_df.reset_index(drop=True, inplace=True)

# %%
base_df.head(2)
# Out:
#    n_rests  n-1
# 0        7  5.0
# 1        7  7.0

# %%
# X DATA... 
X = base_df['n-1']

# Y DATA SPLIT
y = base_df['n_rests']

# Other Variables
test_size = 1
predict = []

# Train, Predict and error.
for x in X[-test_size:]:
    yhat = model_persistence(x)
    predict.append(yhat)
    
mse = mean_squared_error(y[-test_size:], predict)
mae = mean_absolute_error(y[-test_size:], predict)

# %%
print('Prediction = ', yhat, ' -- Vs -- ', 'Original = ', list(y[-test_size:])[0])
print('MAE = ', mae)
print('MSE = ', mse)
# Out:
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0

# %% [markdown]
# #### <span style="background:skyblue"> Baseline CV </span>

# %% [markdown]
# #### <span style="background:skyblue"> TSCV </span>

# %%
# X DATA... 
X = base_df['n-1']

# Y DATA SPLIT
y = base_df['n_rests']

# Other Variables
test_size = 1
predict = []
b_mse = []
b_mae = []
#Split, Train, Predict and error.

tscv = TimeSeriesSplit(max_train_size=None, n_splits = 300, test_size=test_size)

for train_index, test_index in tscv.split(X):
    predict = []
    print('TRAIN:', train_index, 'TEST:', test_index) 
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    for x in X_test:
        yhat = model_persistence(x)
        predict.append(yhat)
        print('X_test = ', x, '-- Predict = ', yhat)
        
    print('Prediction = ', yhat, ' -- Vs -- ', 'Original = ', list(y[-test_size:])[0])
    b_mse.append(mean_squared_error(y_test, predict))
    b_mae.append(mean_absolute_error(y_test, predict))
    print('MAE = ', b_mae[-1])
    print('MSE = ', b_mse[-1])
    print('\n')
    
    
print('Mae Mean = ', np.mean(b_mae))
print('Mse Mean = ', np.mean(b_mse))
print('\n')
# Out:
# TRAIN: [   0    1    2 ... 1757 1758 1759] TEST: [1760]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1758 1759 1760] TEST: [1761]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1759 1760 1761] TEST: [1762]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1760 1761 1762] TEST: [1763]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1761 1762 1763] TEST: [1764]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1762 1763 1764] TEST: [1765]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1763 1764 1765] TEST: [1766]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1764 1765 1766] TEST: [1767]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1765 1766 1767] TEST: [1768]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1766 1767 1768] TEST: [1769]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1767 1768 1769] TEST: [1770]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1768 1769 1770] TEST: [1771]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1769 1770 1771] TEST: [1772]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1770 1771 1772] TEST: [1773]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1771 1772 1773] TEST: [1774]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1772 1773 1774] TEST: [1775]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1773 1774 1775] TEST: [1776]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1774 1775 1776] TEST: [1777]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1775 1776 1777] TEST: [1778]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1776 1777 1778] TEST: [1779]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1777 1778 1779] TEST: [1780]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1778 1779 1780] TEST: [1781]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1779 1780 1781] TEST: [1782]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1780 1781 1782] TEST: [1783]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1781 1782 1783] TEST: [1784]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1782 1783 1784] TEST: [1785]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1783 1784 1785] TEST: [1786]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1784 1785 1786] TEST: [1787]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1785 1786 1787] TEST: [1788]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1786 1787 1788] TEST: [1789]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1787 1788 1789] TEST: [1790]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1788 1789 1790] TEST: [1791]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1789 1790 1791] TEST: [1792]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1790 1791 1792] TEST: [1793]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1791 1792 1793] TEST: [1794]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1792 1793 1794] TEST: [1795]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1793 1794 1795] TEST: [1796]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1794 1795 1796] TEST: [1797]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1795 1796 1797] TEST: [1798]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1796 1797 1798] TEST: [1799]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1797 1798 1799] TEST: [1800]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1798 1799 1800] TEST: [1801]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1799 1800 1801] TEST: [1802]
# X_test =  8.0 -- Predict =  8.0
# Prediction =  8.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1800 1801 1802] TEST: [1803]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1801 1802 1803] TEST: [1804]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  8.0
# MSE =  64.0
#
#
# TRAIN: [   0    1    2 ... 1802 1803 1804] TEST: [1805]
# X_test =  8.0 -- Predict =  8.0
# Prediction =  8.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1803 1804 1805] TEST: [1806]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1804 1805 1806] TEST: [1807]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1805 1806 1807] TEST: [1808]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1806 1807 1808] TEST: [1809]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1807 1808 1809] TEST: [1810]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1808 1809 1810] TEST: [1811]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1809 1810 1811] TEST: [1812]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1810 1811 1812] TEST: [1813]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1811 1812 1813] TEST: [1814]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1812 1813 1814] TEST: [1815]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1813 1814 1815] TEST: [1816]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1814 1815 1816] TEST: [1817]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1815 1816 1817] TEST: [1818]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  7.0
# MSE =  49.0
#
#
# TRAIN: [   0    1    2 ... 1816 1817 1818] TEST: [1819]
# X_test =  11.0 -- Predict =  11.0
# Prediction =  11.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1817 1818 1819] TEST: [1820]
# X_test =  12.0 -- Predict =  12.0
# Prediction =  12.0  -- Vs --  Original =  2
# MAE =  7.0
# MSE =  49.0
#
#
# TRAIN: [   0    1    2 ... 1818 1819 1820] TEST: [1821]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1819 1820 1821] TEST: [1822]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1820 1821 1822] TEST: [1823]
# X_test =  10.0 -- Predict =  10.0
# Prediction =  10.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1821 1822 1823] TEST: [1824]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1822 1823 1824] TEST: [1825]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1823 1824 1825] TEST: [1826]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1824 1825 1826] TEST: [1827]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1825 1826 1827] TEST: [1828]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1826 1827 1828] TEST: [1829]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1827 1828 1829] TEST: [1830]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1828 1829 1830] TEST: [1831]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1829 1830 1831] TEST: [1832]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1830 1831 1832] TEST: [1833]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1831 1832 1833] TEST: [1834]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1832 1833 1834] TEST: [1835]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1833 1834 1835] TEST: [1836]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1834 1835 1836] TEST: [1837]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1835 1836 1837] TEST: [1838]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1836 1837 1838] TEST: [1839]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1837 1838 1839] TEST: [1840]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1838 1839 1840] TEST: [1841]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1839 1840 1841] TEST: [1842]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1840 1841 1842] TEST: [1843]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1841 1842 1843] TEST: [1844]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1842 1843 1844] TEST: [1845]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1843 1844 1845] TEST: [1846]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1844 1845 1846] TEST: [1847]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1845 1846 1847] TEST: [1848]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1846 1847 1848] TEST: [1849]
# X_test =  10.0 -- Predict =  10.0
# Prediction =  10.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1847 1848 1849] TEST: [1850]
# X_test =  12.0 -- Predict =  12.0
# Prediction =  12.0  -- Vs --  Original =  2
# MAE =  9.0
# MSE =  81.0
#
#
# TRAIN: [   0    1    2 ... 1848 1849 1850] TEST: [1851]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1849 1850 1851] TEST: [1852]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1850 1851 1852] TEST: [1853]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1851 1852 1853] TEST: [1854]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1852 1853 1854] TEST: [1855]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1853 1854 1855] TEST: [1856]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1854 1855 1856] TEST: [1857]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1855 1856 1857] TEST: [1858]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1856 1857 1858] TEST: [1859]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1857 1858 1859] TEST: [1860]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1858 1859 1860] TEST: [1861]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1859 1860 1861] TEST: [1862]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1860 1861 1862] TEST: [1863]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1861 1862 1863] TEST: [1864]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1862 1863 1864] TEST: [1865]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1863 1864 1865] TEST: [1866]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1864 1865 1866] TEST: [1867]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1865 1866 1867] TEST: [1868]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1866 1867 1868] TEST: [1869]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1867 1868 1869] TEST: [1870]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1868 1869 1870] TEST: [1871]
# X_test =  9.0 -- Predict =  9.0
# Prediction =  9.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1869 1870 1871] TEST: [1872]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1870 1871 1872] TEST: [1873]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1871 1872 1873] TEST: [1874]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1872 1873 1874] TEST: [1875]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1873 1874 1875] TEST: [1876]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1874 1875 1876] TEST: [1877]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1875 1876 1877] TEST: [1878]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1876 1877 1878] TEST: [1879]
# X_test =  8.0 -- Predict =  8.0
# Prediction =  8.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1877 1878 1879] TEST: [1880]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1878 1879 1880] TEST: [1881]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1879 1880 1881] TEST: [1882]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1880 1881 1882] TEST: [1883]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1881 1882 1883] TEST: [1884]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1882 1883 1884] TEST: [1885]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1883 1884 1885] TEST: [1886]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1884 1885 1886] TEST: [1887]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1885 1886 1887] TEST: [1888]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1886 1887 1888] TEST: [1889]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1887 1888 1889] TEST: [1890]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1888 1889 1890] TEST: [1891]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1889 1890 1891] TEST: [1892]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1890 1891 1892] TEST: [1893]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1891 1892 1893] TEST: [1894]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1892 1893 1894] TEST: [1895]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1893 1894 1895] TEST: [1896]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1894 1895 1896] TEST: [1897]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1895 1896 1897] TEST: [1898]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1896 1897 1898] TEST: [1899]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1897 1898 1899] TEST: [1900]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1898 1899 1900] TEST: [1901]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1899 1900 1901] TEST: [1902]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1900 1901 1902] TEST: [1903]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1901 1902 1903] TEST: [1904]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1902 1903 1904] TEST: [1905]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1903 1904 1905] TEST: [1906]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1904 1905 1906] TEST: [1907]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1905 1906 1907] TEST: [1908]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1906 1907 1908] TEST: [1909]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1907 1908 1909] TEST: [1910]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1908 1909 1910] TEST: [1911]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1909 1910 1911] TEST: [1912]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1910 1911 1912] TEST: [1913]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1911 1912 1913] TEST: [1914]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1912 1913 1914] TEST: [1915]
# X_test =  8.0 -- Predict =  8.0
# Prediction =  8.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1913 1914 1915] TEST: [1916]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1914 1915 1916] TEST: [1917]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1915 1916 1917] TEST: [1918]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1916 1917 1918] TEST: [1919]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1917 1918 1919] TEST: [1920]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1918 1919 1920] TEST: [1921]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1919 1920 1921] TEST: [1922]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1920 1921 1922] TEST: [1923]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1921 1922 1923] TEST: [1924]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1922 1923 1924] TEST: [1925]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1923 1924 1925] TEST: [1926]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  6.0
# MSE =  36.0
#
#
# TRAIN: [   0    1    2 ... 1924 1925 1926] TEST: [1927]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1925 1926 1927] TEST: [1928]
# X_test =  8.0 -- Predict =  8.0
# Prediction =  8.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 1926 1927 1928] TEST: [1929]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1927 1928 1929] TEST: [1930]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1928 1929 1930] TEST: [1931]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1929 1930 1931] TEST: [1932]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1930 1931 1932] TEST: [1933]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1931 1932 1933] TEST: [1934]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1932 1933 1934] TEST: [1935]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1933 1934 1935] TEST: [1936]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1934 1935 1936] TEST: [1937]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1935 1936 1937] TEST: [1938]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1936 1937 1938] TEST: [1939]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1937 1938 1939] TEST: [1940]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1938 1939 1940] TEST: [1941]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1939 1940 1941] TEST: [1942]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1940 1941 1942] TEST: [1943]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1941 1942 1943] TEST: [1944]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1942 1943 1944] TEST: [1945]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1943 1944 1945] TEST: [1946]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1944 1945 1946] TEST: [1947]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1945 1946 1947] TEST: [1948]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1946 1947 1948] TEST: [1949]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1947 1948 1949] TEST: [1950]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1948 1949 1950] TEST: [1951]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1949 1950 1951] TEST: [1952]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1950 1951 1952] TEST: [1953]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1951 1952 1953] TEST: [1954]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1952 1953 1954] TEST: [1955]
# X_test =  9.0 -- Predict =  9.0
# Prediction =  9.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1953 1954 1955] TEST: [1956]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1954 1955 1956] TEST: [1957]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1955 1956 1957] TEST: [1958]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1956 1957 1958] TEST: [1959]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1957 1958 1959] TEST: [1960]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1958 1959 1960] TEST: [1961]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1959 1960 1961] TEST: [1962]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1960 1961 1962] TEST: [1963]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1961 1962 1963] TEST: [1964]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1962 1963 1964] TEST: [1965]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1963 1964 1965] TEST: [1966]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1964 1965 1966] TEST: [1967]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1965 1966 1967] TEST: [1968]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1966 1967 1968] TEST: [1969]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1967 1968 1969] TEST: [1970]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1968 1969 1970] TEST: [1971]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1969 1970 1971] TEST: [1972]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1970 1971 1972] TEST: [1973]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1971 1972 1973] TEST: [1974]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1972 1973 1974] TEST: [1975]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1973 1974 1975] TEST: [1976]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1974 1975 1976] TEST: [1977]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1975 1976 1977] TEST: [1978]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1976 1977 1978] TEST: [1979]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1977 1978 1979] TEST: [1980]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1978 1979 1980] TEST: [1981]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1979 1980 1981] TEST: [1982]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1980 1981 1982] TEST: [1983]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1981 1982 1983] TEST: [1984]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1982 1983 1984] TEST: [1985]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1983 1984 1985] TEST: [1986]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1984 1985 1986] TEST: [1987]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1985 1986 1987] TEST: [1988]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1986 1987 1988] TEST: [1989]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1987 1988 1989] TEST: [1990]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1988 1989 1990] TEST: [1991]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1989 1990 1991] TEST: [1992]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1990 1991 1992] TEST: [1993]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1991 1992 1993] TEST: [1994]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 1992 1993 1994] TEST: [1995]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1993 1994 1995] TEST: [1996]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1994 1995 1996] TEST: [1997]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1995 1996 1997] TEST: [1998]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 1996 1997 1998] TEST: [1999]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 1997 1998 1999] TEST: [2000]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 1998 1999 2000] TEST: [2001]
# X_test =  7.0 -- Predict =  7.0
# Prediction =  7.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 1999 2000 2001] TEST: [2002]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2000 2001 2002] TEST: [2003]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 2001 2002 2003] TEST: [2004]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2002 2003 2004] TEST: [2005]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2003 2004 2005] TEST: [2006]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 2004 2005 2006] TEST: [2007]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2005 2006 2007] TEST: [2008]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2006 2007 2008] TEST: [2009]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 2007 2008 2009] TEST: [2010]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2008 2009 2010] TEST: [2011]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 2009 2010 2011] TEST: [2012]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2010 2011 2012] TEST: [2013]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 2011 2012 2013] TEST: [2014]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 2012 2013 2014] TEST: [2015]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2013 2014 2015] TEST: [2016]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2014 2015 2016] TEST: [2017]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2015 2016 2017] TEST: [2018]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2016 2017 2018] TEST: [2019]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2017 2018 2019] TEST: [2020]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2018 2019 2020] TEST: [2021]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 2019 2020 2021] TEST: [2022]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2020 2021 2022] TEST: [2023]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2021 2022 2023] TEST: [2024]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2022 2023 2024] TEST: [2025]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2023 2024 2025] TEST: [2026]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2024 2025 2026] TEST: [2027]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2025 2026 2027] TEST: [2028]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 2026 2027 2028] TEST: [2029]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2027 2028 2029] TEST: [2030]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2028 2029 2030] TEST: [2031]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2029 2030 2031] TEST: [2032]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2030 2031 2032] TEST: [2033]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 2031 2032 2033] TEST: [2034]
# X_test =  8.0 -- Predict =  8.0
# Prediction =  8.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 2032 2033 2034] TEST: [2035]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2033 2034 2035] TEST: [2036]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2034 2035 2036] TEST: [2037]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2035 2036 2037] TEST: [2038]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2036 2037 2038] TEST: [2039]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2037 2038 2039] TEST: [2040]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2038 2039 2040] TEST: [2041]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2039 2040 2041] TEST: [2042]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2040 2041 2042] TEST: [2043]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2041 2042 2043] TEST: [2044]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2042 2043 2044] TEST: [2045]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2043 2044 2045] TEST: [2046]
# X_test =  5.0 -- Predict =  5.0
# Prediction =  5.0  -- Vs --  Original =  2
# MAE =  4.0
# MSE =  16.0
#
#
# TRAIN: [   0    1    2 ... 2044 2045 2046] TEST: [2047]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  5.0
# MSE =  25.0
#
#
# TRAIN: [   0    1    2 ... 2045 2046 2047] TEST: [2048]
# X_test =  6.0 -- Predict =  6.0
# Prediction =  6.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2046 2047 2048] TEST: [2049]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2047 2048 2049] TEST: [2050]
# X_test =  0.0 -- Predict =  0.0
# Prediction =  0.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2048 2049 2050] TEST: [2051]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  0.0
# MSE =  0.0
#
#
# TRAIN: [   0    1    2 ... 2049 2050 2051] TEST: [2052]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2050 2051 2052] TEST: [2053]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2051 2052 2053] TEST: [2054]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2052 2053 2054] TEST: [2055]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2053 2054 2055] TEST: [2056]
# X_test =  1.0 -- Predict =  1.0
# Prediction =  1.0  -- Vs --  Original =  2
# MAE =  3.0
# MSE =  9.0
#
#
# TRAIN: [   0    1    2 ... 2054 2055 2056] TEST: [2057]
# X_test =  4.0 -- Predict =  4.0
# Prediction =  4.0  -- Vs --  Original =  2
# MAE =  2.0
# MSE =  4.0
#
#
# TRAIN: [   0    1    2 ... 2055 2056 2057] TEST: [2058]
# X_test =  2.0 -- Predict =  2.0
# Prediction =  2.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# TRAIN: [   0    1    2 ... 2056 2057 2058] TEST: [2059]
# X_test =  3.0 -- Predict =  3.0
# Prediction =  3.0  -- Vs --  Original =  2
# MAE =  1.0
# MSE =  1.0
#
#
# Mae Mean =  1.9533333333333334
# Mse Mean =  6.52

# %% [markdown]
# #### <span style="background:skyblue"> BCV </span>

# %%
# X DATA... 
X = base_df['n-1']

# Y DATA SPLIT
y = base_df['n_rests']

# Other Variables
test_size = 1
predict = []
b_mse = []
b_mae = []
#Split, Train, Predict and error.

tscv = BlockingTimeSeriesSplit(n_splits = 300)

for train_index, test_index in tscv.split(X):
    predict = []
    print('TRAIN:', train_index, 'TEST:', test_index) 
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    for x in X_test:
        yhat = model_persistence(x)
        predict.append(yhat)
        print('X_test = ', x, '-- Predict = ', yhat)
        
    print('Prediction = ', yhat, ' -- Vs -- ', 'Original = ', list(y[-test_size:])[0])
    b_mse.append(mean_squared_error(y_test, predict))
    b_mae.append(mean_absolute_error(y_test, predict))
    print('MAE = ', b_mae[-1])
    print('MSE = ', b_mse[-1])
    print('\n')
    
    
print('Mae Mean = ', np.mean(b_mae))
print('Mse Mean = ', np.mean(b_mse))
print('\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 16>()
#      12 #Split, Train, Predict and error.
#      14 tscv = BlockingTimeSeriesSplit(n_splits = 2)
# ---> 16 for train_index, test_index in tscv.split(X):
#      17     predict = []
#      18     print('TRAIN:', train_index, 'TEST:', test_index)
#
# Input In [9], in BlockingTimeSeriesSplit.split(self, X, y, groups, num_splits)
#       8 def split(self, X, y=None, groups=None, num_splits=None):
#       9     n_samples = len(X)
# ---> 10     k_fold_size = n_samples // num_splits
#      11     indices = np.arange(n_samples)
#      13     margin = 0
#
# TypeError: unsupported operand type(s) for //: 'int' and 'NoneType'

# %% [markdown]
# # <span style="background:lightgreen"> Como se puede ver, los Errores de este método son bastante pequeños, por lo que es posible que no haga falta ni realizar predicciones con RandomForest  <span>
